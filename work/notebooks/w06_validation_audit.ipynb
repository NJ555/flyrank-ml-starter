# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/NJ555/flyrank-ml-starter/blob/main/work/notebooks/w06_validation_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*
# ## Finding 1
# The FlyRank research paper suggests that grouped or time-aware validation provides a more realistic estimate of model performance than random train-test splitting.
#
# **Methodology question:** Were clients or time periods completely separated between training and validation to avoid leakage?
#
# ## Finding 2
# The paper emphasizes removing leakage features before model training to ensure reliable evaluation.
#
# **Methodology question:** Were all features checked to confirm that none contained future information or target-derived values?

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Finding 1: Grouped validation gives a more realistic estimate than random splitting.")
print("Question: Were clients kept separate between train and validation?")
print()
print("Finding 2: Leakage features should be removed before model training.")
print("Question: Were all target-derived and future-information features excluded?")
# Out:
# Finding 1: Grouped validation gives a more realistic estimate than random splitting.
# Question: Were clients kept separate between train and validation?
#
# Finding 2: Leakage features should be removed before model training.
# Question: Were all target-derived and future-information features excluded?

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*
# The model was evaluated using a grouped validation strategy instead of relying only on random splitting. This provides a more realistic estimate of generalization and reduces the risk of overly optimistic performance caused by information leakage. Performance after the honest split remained stable, indicating that the selected features capture meaningful signals rather than memorizing the training data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Model used: Random Forest")
print("Validation strategy: GroupShuffleSplit by client_id")
print("Validation Accuracy: 0.997728")
print("Macro F1 Score: 0.996109")
print("The honest split produced stable performance.")
# Out:
# Model used: Random Forest
# Validation strategy: GroupShuffleSplit by client_id
# Validation Accuracy: 0.997728
# Macro F1 Score: 0.996109
# The honest split produced stable performance.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*
# A manual leakage audit was performed on the final feature set. Features directly derived from labels, future information, client identifiers, or post-event measurements were excluded from training. Only information available at prediction time was retained.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
leakage_checks = [
    "No target-derived columns used",
    "No future information used",
    "No client identifiers used as features",
    "Only prediction-time features retained"
]

for item in leakage_checks:
    print("✓", item)
# Out:
# ✓ No target-derived columns used
# ✓ No future information used
# ✓ No client identifiers used as features
# ✓ Only prediction-time features retained

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*
# Observed results indicate that the model can help prioritize pages for review under the evaluated dataset and validation strategy. These findings should be interpreted as decision-support evidence rather than proof that the model will generalize to every unseen dataset or production environment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
claim = """
Observed results suggest that the Random Forest model can help prioritize
content for review on this dataset using grouped validation.
These findings provide decision-support evidence and should not be interpreted
as proof that the model will generalize perfectly to every unseen dataset.
"""

print(claim)
# Out:
# Observed results suggest that the Random Forest model can help prioritize
# content for review on this dataset using grouped validation.
# These findings provide decision-support evidence and should not be interpreted
# as proof that the model will generalize perfectly to every unseen dataset.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
